# %% [markdown]
# # My Jupyter Notebook on Watson Studio

# %% [markdown]
# **Nipun Tharinda**
# Data analytics

# %% [markdown]
# *Data science create curiosity and a path for innovations.*

# %% [markdown]
# ### Python

# %%
1+1
# Out:
# 2

# %% [markdown]
# ![images.png](attachment:images.png)

# %% [markdown]
#   _*
#   _*
#   _*

# %% [markdown]
# 1. cat
# 2. rat
# 3. man

# %% [markdown]
# _ _[link text]_ _https://eu-de.dataplatform.cloud.ibm.com/analytics/notebooks/v2/3e25ab87-b44e-4eb0-adf5-9ec8b0fd9e65?projectid=183143ed-38d2-40d2-afe1-08cb735ef5bd&context=cpdaas
